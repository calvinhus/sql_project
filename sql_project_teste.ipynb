# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 5-6 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {   
'ironhack' : 10828,
'app-academy' : 10525,
'springboard' : 11035    
}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# ironhack
# app-academy
# springboard

# %%
comments.head()
# Out:
#        id            name  anonymous hostProgramName  graduatingYear  \
# 0  284372           James      False            None          2021.0
# 1  284341     Hugo Michon      False            None          2021.0
# 2  284279   Kimera Joseph      False            None          2021.0
# 3  283970       Anonymous       True            None          2021.0
# 4  283920  Pekka Tiitinen      False            None          2021.0
#
#    isAlumni                 jobTitle  \
# 0     False         UX / UI Designer
# 1      True   Cyber security analyst
# 2     False            Data Engineer
# 3      True  Innovation and strategy
# 4     False
#
#                                              tagline  \
# 0          From teacher to UX/UI designer in 9 weeks
# 1                            Exhausting but worth it
# 2                            Build ETL/ELT pipelines
# 3  Although there are some things I suggest to im...
# 4                                 Amazing experience
#
#                                                 body  \
# 0  <span class="truncatable"><p></p><p>I came int...
# 1  <span class="truncatable"><p></p><p>I did a fu...
# 2  <span class="truncatable"><p></p><p>Pros - Gre...
# 3  <span class="truncatable"><p></p><p>Pros - Abh...
# 4  <span class="truncatable"><p></p><p>Very in de...
#
#                                              rawBody  ...   queryDate  \
# 0  <p>I came into the Ironhack full-time remote b...  ...  2021-12-21
# 1  <p>I did a full time remote bootcamp for cyber...  ...  2021-12-20
# 2  <p>Pros - Great tutors. Lead teachers and tuto...  ...  2021-12-18
# 3  <p>Pros - Abhi is really talented as a teacher...  ...  2021-12-07
# 4  <p>Very in depth content and a hands on approa...  ...  2021-12-05
#
#                      program             user overallScore comments overall  \
# 0      UX/UI Design Bootcamp  {'image': None}          5.0       []     5.0
# 1    Cyber Security Bootcamp  {'image': None}          5.0       []     5.0
# 2    Data Analytics Bootcamp  {'image': None}          4.7       []     5.0
# 3   Data Analytics Part-Time  {'image': None}          3.7       []     4.0
# 4  Web Development Part-Time  {'image': None}          4.7       []     5.0
#
#   curriculum jobSupport                                        review_body  \
# 0        5.0        5.0  I came into the Ironhack full-time remote boot...
# 1        5.0        5.0  I did a full time remote bootcamp for cybersec...
# 2        4.0        5.0  Pros - Great tutors. Lead teachers and tutors ...
# 3        4.0        3.0  Pros - Abhi is really talented as a teacher. H...
# 4        5.0        4.0  Very in depth content and a hands on approach ...
#
#      school
# 0  ironhack
# 1  ironhack
# 2  ironhack
# 3  ironhack
# 4  ironhack
#
# [5 rows x 21 columns]

# %%
comments[comments['school']=='ironhack']['program'].unique()
# Out:
# array(['UX/UI Design Bootcamp', 'Cyber Security Bootcamp',
#        'Data Analytics Bootcamp', 'Data Analytics Part-Time',
#        'Web Development Part-Time', 'Web Development Bootcamp', '', None,
#        'UX/UI Design Part-Time', 'Full-time Web Development Bootcamp',
#        'Full-time UX/UI Design Bootcamp', 'Part-time Web Development',
#        'Part-time UX/UI Design', 'Full-time Web Development Bootcamp ',
#        'Part-time UX/UI Design ', 'Web Design'], dtype=object)

# %%
comments2=comments.copy()

# %%
def program_clean(row):
    if (row['program']=='Full-time UX/UI Design Bootcamp')|(row['program']=='Web Design'):
        return 'UX/UI Design Bootcamp'
    elif (row['program']=='Part-time UX/UI Design')|(row['program']=='Part-time UX/UI Design '):
        return 'UX/UI Design Part-Time'
    elif (row['program']=='Full-time Web Development Bootcamp')|(row['program']=='Full-time Web Development Bootcamp '):
        return 'Web Development Bootcamp'
    elif (row['program']=='Part-time Web Development'):
        return 'Web Development Part-Time'
    elif (row['program']==''):
        return None
    else:
        return row['program']

# %%
comments2['program']=comments2.apply(program_clean, axis=1)

# %%
comments2[comments2['school']=='ironhack']['program'].unique()
# Out:
# array(['UX/UI Design Bootcamp', 'Cyber Security Bootcamp',
#        'Data Analytics Bootcamp', 'Data Analytics Part-Time',
#        'Web Development Part-Time', 'Web Development Bootcamp', None,
#        'UX/UI Design Part-Time'], dtype=object)

# %%
comments2[comments2['school']=='ironhack']['jobTitle'].fillna("No info")
# Out:
# 0                              UX / UI Designer
# 1                        Cyber security analyst
# 2                                 Data Engineer
# 3                       Innovation and strategy
# 4
#                          ...
# 1092                                    No info
# 1093                              iOS Developer
# 1094                               Entrepreneur
# 1095                                    No info
# 1096    Founder, RoR Developer @ Decorissimo.es
# Name: jobTitle, Length: 1097, dtype: object

# %%
comments2[comments2['school']=='ironhack']['jobTitle'].unique()
# Out:
# array(['UX / UI Designer', 'Cyber security analyst', 'Data Engineer',
#        'Innovation and strategy', '', 'Full stack Javascript developer',
#        'UX/UI Designer', 'UX UI Designer', 'Full-Stack developer',
#        'Web developer', 'Product Designer', 'Full Stack Developer',
#        'full stack developer', 'UXUI Designer', 'Frontend Developer',
#        'Product designer', 'ux ui designer', 'web dev fullstack',
#        'Junior Data Analyst', 'Data Analyst', 'Web Developer',
#        'Junior Web Dev', 'UX/UI designer', 'Growth engineer/marketer',
#        'Senior Associate', 'Data Analytics', 'Software Engineer',
#        'Ux ui designer', 'ux/ui product designer',
#        'Fullstack web developer', 'Full stack developer',
#        'Development Operations Engineer', 'Web Dev', 'UX Designer',
#        'Full-Stack Web Developer', 'Student',
#        'Head of Sales / Fullstack developer',
#        'Power BI Junior Consultant', 'UX/UI Design',
#        'Full Stack Web Developer', 'unemployed', 'frontend developer',
#        'UX designer', 'Web Developer junior', 'web dev', 'web developper',
#        'Unemployed', 'UI Designer', 'CoFounder of Botcave SAS',
#        'Data  analyst', 'Fullstack Web Developer',
#        'Learning and Development Specialist', 'Ux/Ui Designer',
#        'Junior Front End Developer', 'Junior Software Developer',
#        'React Developer', 'UX-UI designer', 'Full stack web developer',
#        'Software Developer Jr., Data Analyst Jr., Structural engineering PhD.',
#        'Graphic Designer', 'UX-designer', 'Front-End Developer',
#        'Insights Project Manager', 'Designer',
#        'full stack web developer/teacher', 'Growth',
#        'Full-stack Web Developer', 'Full-stack web-developer',
#        'Junior UI Developer', 'Product Manager', 'Full-stack developer',
#        'Front End Developer', 'Data Analytics Student',
#        'Software Developer', 'Web Dev TA', 'Junior data analyst',
#        'Finance Analyst', 'UX Designer/UX Writer', 'Data analyst',
#        'Engenheira de dados', 'Senior software engineer', 'Front End Dev',
#        'Full stack Developer', 'JavaScript Developer', 'UX UI designer',
#        'ux/ui designer', 'Junior Web Developer', 'Head of design',
#        'Data Science and Advanced Analytics Manager', 'Developer',
#        'Program Manager', 'Teacher Assistant', None,
#        'Web Dev.  Full Stack', 'Full Stack web developer', 'Software Dev',
#        'Web dev Full Stack', 'Jr Fullstack web developer',
#        'Jr Full Stack Developer', 'Web Developer Full Stack',
#        'Developer Trainee', 'Junior Product Designer',
#        'Junior Webdeveloper', 'Interactive Developer', 'Web-dev',
#        'web dev student', 'Junior Full Stack Web Dev',
#        'Full Stack Developer Junior', 'Full stack web dev',
#        'Front-End Web Developer', 'UX DESIGNER', 'Web Development ',
#        'Computer software engineer', 'Support engineer',
#        'UX - UI Designer', 'Web dev', 'Software Engineer ',
#        'UX/UI and graphic designer', 'UX UI Design',
#        'Front end web developer',
#        'Fullstack web developer &amp; Teach assistant',
#        'UX UI Designer Junior',
#        'Freelancing UX/UI Designer &amp; Travel agent', 'Web Dev.',
#        'IT Consultant', 'UX/UI', 'UX &amp; UI Designer',
#        'Estudiante de desarrollo web', 'full stack web developer',
#        'Full Stack Dev', 'Jr Full Stack developer',
#        'Junior Fullstack Developer', 'Junior Full Stack Developer',
#        'Full-Stack Developer', 'Therapist', 'Web Content Analyst',
#        'Javascript Engineer', 'UX DEsigner', 'co-founder at Leemur',
#        'Ux/UI Designer', 'Junior backend developer', 'Creative Designer',
#        'UX/UI Design Teacher Assistant', 'Web Development',
#        'RPA Developer', 'Associate Software Engineer', 'Web development',
#        'Customer Success Associate at Nuvola', 'General Manager',
#        'Freelance Full Stack Web Developer', 'TPT Business Development',
#        'TA at Ironhack', 'UX/UI Designer ', 'Ironhack Graduate',
#        'Creative Team Lead', 'Association Web Engineer',
#        'Creative Manager', 'Creative Development Manager',
#        'Teacher Assistant at Ironhack', 'Full Stack Web Developer ',
#        'Interaction Designer', 'Front-end developer',
#        'Full mern stack student', 'Full-stack Developer',
#        'Teacher Assistant @ Ironhack Paris',
#        'UX Designer and Full Stack Developer', 'Fullstack developer',
#        'Product Owner', 'Teaching Assistant', 'Partner @Orion',
#        'Analytics Consultant', 'Full Stack', 'Ux Ui Designer',
#        'Front-End Developer Junior', 'Associate Front End Web Developer',
#        'UX/UI designer M.A Visual and Performing Arts', 'UXUI designer',
#        'Former UX/UI Student', 'student', 'UX/UI design',
#        'Technical Recruiter ', 'Industrial/ Graphic and UX/UI Designer ',
#        'Owner', 'Full Stack Developer || Digital Analyst',
#        'Web Designer &amp; Developer', 'Director of Ecommerce Operations',
#        'Programmer Analyst', 'Programmer', 'Project Manager',
#        'Software Architect', 'UX Researcher',
#        'Frontend Developer at Cabify', 'Desarrollador Front-end',
#        'Designer and Front-End Developer', 'UX ', 'UX&amp;UI Designer',
#        'UX/UI Designer &amp; Front End Developer',
#        'Architect &amp; UX/UI Designer', 'UX7UI',
#        'Engineer L1 - Full Stack Web Developer', 'Junior .Net Developer',
#        'Solution Architect', 'Founder', 'Product Designer ',
#        'TA Ironhack', 'FullStack Developer', 'Jr Web Developer',
#        'Product Designer &amp; Full Stack Developer',
#        'Diseñador de Producto',
#        'Full Stack Web Developer - JavaScript, MongoDB, Express, Angular 4, Node.js',
#        'Marketing &amp; UX specialist', 'OUwebs Founder',
#        'Business School Student', 'Javascript Developer',
#        'Founder Billin', 'UX/UI DESIGNER',
#        'Junior Web Application Developer', 'service designer',
#        'UX/ UI Designer', 'Frontend developer ', 'Experience Designer',
#        'Web Applications Developer', 'Junior Associate Web Developer',
#        'Front-End Engineer', 'Front End Web Developer',
#        'Software Development Engineer',
#        'Front End Developer at TransUnion', 'HIT Consultant ',
#        'Frontend Developer &amp; UXUI', 'Staff Software Engineer',
#        'Assistant teacher', 'IT Director', 'Lead Software Engineer',
#        'UCLA Student', 'Front-end Developer', 'COO at Tender.co',
#        'IT Trainer', 'UX / UI &amp; Front End Designer',
#        'JavaScript Engineer', 'Java Full-Stack Developer',
#        'Product Developer', 'Jr UX Architec', 'Fullstack Developer',
#        'Digital Product Designer', 'LEAD UX/UI', 'Contract Web Developer',
#        'Web Application Developer', 'IB Analyst',
#        'Full Stack Web Developper', 'Lead UX at Loycus',
#        'Junior JavaScript Application Developer', 'Backend Developer',
#        'Digital Analyst', 'Founder, Donkies Technologies',
#        'Digital Product Manager', 'IT Recruiter', 'Jr. Developer',
#        'Front End Engineer', 'Sr. Digital Account Manager',
#        'iOS Developer', 'Entrepreneur',
#        'Founder, RoR Developer @ Decorissimo.es'], dtype=object)

# %%
print(comments2[comments2['school']=='ironhack']['jobTitle'].str.replace(" ", "No info"))
# Out:
# 0                      UXNo info/No infoUINo infoDesigner
# 1                      CyberNo infosecurityNo infoanalyst
# 2                                     DataNo infoEngineer
# 3                     InnovationNo infoandNo infostrategy
# 4
#                               ...
# 1092                                                 None
# 1093                                  iOSNo infoDeveloper
# 1094                                         Entrepreneur
# 1095                                                 None
# 1096    Founder,No infoRoRNo infoDeveloperNo info@No i...
# Name: jobTitle, Length: 1097, dtype: object

# %%
comments2[comments2['school']=='ironhack']['jobTitle'].unique()
# Out:
# array(['UX / UI Designer', 'Cyber security analyst', 'Data Engineer',
#        'Innovation and strategy', '', 'Full stack Javascript developer',
#        'UX/UI Designer', 'UX UI Designer', 'Full-Stack developer',
#        'Web developer', 'Product Designer', 'Full Stack Developer',
#        'full stack developer', 'UXUI Designer', 'Frontend Developer',
#        'Product designer', 'ux ui designer', 'web dev fullstack',
#        'Junior Data Analyst', 'Data Analyst', 'Web Developer',
#        'Junior Web Dev', 'UX/UI designer', 'Growth engineer/marketer',
#        'Senior Associate', 'Data Analytics', 'Software Engineer',
#        'Ux ui designer', 'ux/ui product designer',
#        'Fullstack web developer', 'Full stack developer',
#        'Development Operations Engineer', 'Web Dev', 'UX Designer',
#        'Full-Stack Web Developer', 'Student',
#        'Head of Sales / Fullstack developer',
#        'Power BI Junior Consultant', 'UX/UI Design',
#        'Full Stack Web Developer', 'unemployed', 'frontend developer',
#        'UX designer', 'Web Developer junior', 'web dev', 'web developper',
#        'Unemployed', 'UI Designer', 'CoFounder of Botcave SAS',
#        'Data  analyst', 'Fullstack Web Developer',
#        'Learning and Development Specialist', 'Ux/Ui Designer',
#        'Junior Front End Developer', 'Junior Software Developer',
#        'React Developer', 'UX-UI designer', 'Full stack web developer',
#        'Software Developer Jr., Data Analyst Jr., Structural engineering PhD.',
#        'Graphic Designer', 'UX-designer', 'Front-End Developer',
#        'Insights Project Manager', 'Designer',
#        'full stack web developer/teacher', 'Growth',
#        'Full-stack Web Developer', 'Full-stack web-developer',
#        'Junior UI Developer', 'Product Manager', 'Full-stack developer',
#        'Front End Developer', 'Data Analytics Student',
#        'Software Developer', 'Web Dev TA', 'Junior data analyst',
#        'Finance Analyst', 'UX Designer/UX Writer', 'Data analyst',
#        'Engenheira de dados', 'Senior software engineer', 'Front End Dev',
#        'Full stack Developer', 'JavaScript Developer', 'UX UI designer',
#        'ux/ui designer', 'Junior Web Developer', 'Head of design',
#        'Data Science and Advanced Analytics Manager', 'Developer',
#        'Program Manager', 'Teacher Assistant', None,
#        'Web Dev.  Full Stack', 'Full Stack web developer', 'Software Dev',
#        'Web dev Full Stack', 'Jr Fullstack web developer',
#        'Jr Full Stack Developer', 'Web Developer Full Stack',
#        'Developer Trainee', 'Junior Product Designer',
#        'Junior Webdeveloper', 'Interactive Developer', 'Web-dev',
#        'web dev student', 'Junior Full Stack Web Dev',
#        'Full Stack Developer Junior', 'Full stack web dev',
#        'Front-End Web Developer', 'UX DESIGNER', 'Web Development ',
#        'Computer software engineer', 'Support engineer',
#        'UX - UI Designer', 'Web dev', 'Software Engineer ',
#        'UX/UI and graphic designer', 'UX UI Design',
#        'Front end web developer',
#        'Fullstack web developer &amp; Teach assistant',
#        'UX UI Designer Junior',
#        'Freelancing UX/UI Designer &amp; Travel agent', 'Web Dev.',
#        'IT Consultant', 'UX/UI', 'UX &amp; UI Designer',
#        'Estudiante de desarrollo web', 'full stack web developer',
#        'Full Stack Dev', 'Jr Full Stack developer',
#        'Junior Fullstack Developer', 'Junior Full Stack Developer',
#        'Full-Stack Developer', 'Therapist', 'Web Content Analyst',
#        'Javascript Engineer', 'UX DEsigner', 'co-founder at Leemur',
#        'Ux/UI Designer', 'Junior backend developer', 'Creative Designer',
#        'UX/UI Design Teacher Assistant', 'Web Development',
#        'RPA Developer', 'Associate Software Engineer', 'Web development',
#        'Customer Success Associate at Nuvola', 'General Manager',
#        'Freelance Full Stack Web Developer', 'TPT Business Development',
#        'TA at Ironhack', 'UX/UI Designer ', 'Ironhack Graduate',
#        'Creative Team Lead', 'Association Web Engineer',
#        'Creative Manager', 'Creative Development Manager',
#        'Teacher Assistant at Ironhack', 'Full Stack Web Developer ',
#        'Interaction Designer', 'Front-end developer',
#        'Full mern stack student', 'Full-stack Developer',
#        'Teacher Assistant @ Ironhack Paris',
#        'UX Designer and Full Stack Developer', 'Fullstack developer',
#        'Product Owner', 'Teaching Assistant', 'Partner @Orion',
#        'Analytics Consultant', 'Full Stack', 'Ux Ui Designer',
#        'Front-End Developer Junior', 'Associate Front End Web Developer',
#        'UX/UI designer M.A Visual and Performing Arts', 'UXUI designer',
#        'Former UX/UI Student', 'student', 'UX/UI design',
#        'Technical Recruiter ', 'Industrial/ Graphic and UX/UI Designer ',
#        'Owner', 'Full Stack Developer || Digital Analyst',
#        'Web Designer &amp; Developer', 'Director of Ecommerce Operations',
#        'Programmer Analyst', 'Programmer', 'Project Manager',
#        'Software Architect', 'UX Researcher',
#        'Frontend Developer at Cabify', 'Desarrollador Front-end',
#        'Designer and Front-End Developer', 'UX ', 'UX&amp;UI Designer',
#        'UX/UI Designer &amp; Front End Developer',
#        'Architect &amp; UX/UI Designer', 'UX7UI',
#        'Engineer L1 - Full Stack Web Developer', 'Junior .Net Developer',
#        'Solution Architect', 'Founder', 'Product Designer ',
#        'TA Ironhack', 'FullStack Developer', 'Jr Web Developer',
#        'Product Designer &amp; Full Stack Developer',
#        'Diseñador de Producto',
#        'Full Stack Web Developer - JavaScript, MongoDB, Express, Angular 4, Node.js',
#        'Marketing &amp; UX specialist', 'OUwebs Founder',
#        'Business School Student', 'Javascript Developer',
#        'Founder Billin', 'UX/UI DESIGNER',
#        'Junior Web Application Developer', 'service designer',
#        'UX/ UI Designer', 'Frontend developer ', 'Experience Designer',
#        'Web Applications Developer', 'Junior Associate Web Developer',
#        'Front-End Engineer', 'Front End Web Developer',
#        'Software Development Engineer',
#        'Front End Developer at TransUnion', 'HIT Consultant ',
#        'Frontend Developer &amp; UXUI', 'Staff Software Engineer',
#        'Assistant teacher', 'IT Director', 'Lead Software Engineer',
#        'UCLA Student', 'Front-end Developer', 'COO at Tender.co',
#        'IT Trainer', 'UX / UI &amp; Front End Designer',
#        'JavaScript Engineer', 'Java Full-Stack Developer',
#        'Product Developer', 'Jr UX Architec', 'Fullstack Developer',
#        'Digital Product Designer', 'LEAD UX/UI', 'Contract Web Developer',
#        'Web Application Developer', 'IB Analyst',
#        'Full Stack Web Developper', 'Lead UX at Loycus',
#        'Junior JavaScript Application Developer', 'Backend Developer',
#        'Digital Analyst', 'Founder, Donkies Technologies',
#        'Digital Product Manager', 'IT Recruiter', 'Jr. Developer',
#        'Front End Engineer', 'Sr. Digital Account Manager',
#        'iOS Developer', 'Entrepreneur',
#        'Founder, RoR Developer @ Decorissimo.es'], dtype=object)

# %%
comments2[(comments2['school']=='ironhack')&(comments2['program']=='Data Analytics Bootcamp')]['jobTitle'].unique()
# Out:
# array(['Data Engineer', '', 'Junior Data Analyst', 'Data Analyst',
#        'Data  analyst',
#        'Software Developer Jr., Data Analyst Jr., Structural engineering PhD.',
#        'Software Engineer', 'Insights Project Manager',
#        'Data Analytics Student', 'Junior data analyst', 'Data analyst',
#        'Engenheira de dados',
#        'Data Science and Advanced Analytics Manager', None], dtype=object)

# %%
comments2[(comments2['school']=='ironhack')&(comments2['program']=='Data Analytics Part-Time')]['jobTitle'].unique()
# Out:
# array(['Innovation and strategy', ''], dtype=object)

# %%
comments2[(comments2['school']=='ironhack')&(comments2['program']=='Cyber Security Bootcamp')]['jobTitle'].unique()
# Out:
# array(['Cyber security analyst'], dtype=object)

# %%
comments2[(comments2['school']=='ironhack')&(comments2['program']=='Cyber Security Part-Time')]['jobTitle'].unique()
# Out:
# array([], dtype=object)

# %%
def jobTitle_CS_clean(row):
    jobTitle_CS =['analyst']
    for element in jobTitle_CS:
        if (element in row):
            return 1
        else:
            return 0

comments2['Work_inField']=comments2['jobTitle'].apply(jobTitle_CS_clean)

# %%
comments2[(comments2['school']=='ironhack')&((comments2['program']=='Web Development Bootcamp')|(comments2['program']=='Web Development Part-Time'))]['jobTitle'].unique()
# Out:
# array(['', 'Full stack Javascript developer', 'Full-Stack developer',
#        'Web developer', 'Full Stack Developer', 'full stack developer',
#        'Frontend Developer', 'web dev fullstack', 'Web Developer',
#        'Junior Web Dev', 'Growth engineer/marketer', 'Senior Associate',
#        'Software Engineer', 'Fullstack web developer',
#        'Full stack developer', 'Development Operations Engineer',
#        'Web Dev', 'Full-Stack Web Developer',
#        'Head of Sales / Fullstack developer', 'Full Stack Web Developer',
#        'unemployed', 'frontend developer', 'Web Developer junior',
#        'web dev', 'web developper', 'CoFounder of Botcave SAS',
#        'Fullstack Web Developer', 'Junior Front End Developer',
#        'Junior Software Developer', 'React Developer',
#        'Full stack web developer', 'Graphic Designer', 'UX-designer',
#        'Front-End Developer', 'full stack web developer/teacher',
#        'Growth', 'Full-stack Web Developer', 'Full-stack web-developer',
#        'Product Manager', 'Full-stack developer', 'Front End Developer',
#        'Software Developer', 'Web Dev TA', 'Finance Analyst',
#        'Senior software engineer', 'Front End Dev',
#        'Full stack Developer', 'JavaScript Developer',
#        'Junior Web Developer', 'Developer', 'Program Manager',
#        'Teacher Assistant', None, 'Web Dev.  Full Stack',
#        'Full Stack web developer', 'Web dev Full Stack',
#        'Jr Fullstack web developer', 'Jr Full Stack Developer',
#        'Web Developer Full Stack', 'Developer Trainee',
#        'Junior Webdeveloper', 'Interactive Developer', 'Web-dev',
#        'web dev student', 'Junior Full Stack Web Dev',
#        'Full Stack Developer Junior', 'Full stack web dev',
#        'Front-End Web Developer', 'Web Development ',
#        'Computer software engineer', 'Support engineer', 'Web dev',
#        'Software Engineer ', 'Front end web developer',
#        'Fullstack web developer &amp; Teach assistant', 'Web Dev.',
#        'IT Consultant', 'Estudiante de desarrollo web',
#        'full stack web developer', 'Full Stack Dev',
#        'Jr Full Stack developer', 'Junior Fullstack Developer',
#        'Junior Full Stack Developer', 'Full-Stack Developer', 'Therapist',
#        'Web Content Analyst', 'Javascript Engineer',
#        'Junior backend developer', 'Web Development', 'RPA Developer',
#        'Associate Software Engineer', 'Web development',
#        'Customer Success Associate at Nuvola', 'General Manager',
#        'Freelance Full Stack Web Developer', 'TPT Business Development',
#        'TA at Ironhack', 'Ironhack Graduate', 'Association Web Engineer',
#        'Teacher Assistant at Ironhack', 'Full Stack Web Developer ',
#        'Front-end developer', 'Student', 'Full mern stack student',
#        'Full-stack Developer', 'Teacher Assistant @ Ironhack Paris',
#        'UX Designer and Full Stack Developer', 'Fullstack developer',
#        'Product Owner', 'Teaching Assistant', 'Partner @Orion',
#        'Analytics Consultant', 'Full Stack', 'Front-End Developer Junior',
#        'Associate Front End Web Developer', 'Technical Recruiter ',
#        'Full Stack Developer || Digital Analyst',
#        'Web Designer &amp; Developer', 'Programmer Analyst', 'Programmer',
#        'Software Architect', 'Frontend Developer at Cabify',
#        'Desarrollador Front-end', 'Designer and Front-End Developer',
#        'Engineer L1 - Full Stack Web Developer', 'Junior .Net Developer',
#        'Solution Architect', 'Founder', 'TA Ironhack',
#        'FullStack Developer', 'Jr Web Developer',
#        'Product Designer &amp; Full Stack Developer',
#        'Full Stack Web Developer - JavaScript, MongoDB, Express, Angular 4, Node.js',
#        'OUwebs Founder', 'Business School Student',
#        'Javascript Developer', 'Founder Billin',
#        'Junior Web Application Developer', 'Frontend developer ',
#        'Web Applications Developer', 'Junior Associate Web Developer',
#        'Front-End Engineer', 'Front End Web Developer',
#        'Software Development Engineer',
#        'Front End Developer at TransUnion',
#        'Frontend Developer &amp; UXUI', 'Staff Software Engineer',
#        'Assistant teacher', 'IT Director', 'Lead Software Engineer',
#        'UCLA Student', 'Front-end Developer', 'COO at Tender.co',
#        'IT Trainer', 'JavaScript Engineer', 'Java Full-Stack Developer',
#        'Product Developer', 'Fullstack Developer',
#        'Contract Web Developer', 'Web Application Developer',
#        'IB Analyst', 'Junior JavaScript Application Developer',
#        'Digital Analyst', 'Founder, Donkies Technologies', 'IT Recruiter',
#        'Jr. Developer', 'Front End Engineer',
#        'Sr. Digital Account Manager', 'iOS Developer', 'Entrepreneur',
#        'Founder, RoR Developer @ Decorissimo.es'], dtype=object)

# %%
comments2[(comments2['school']=='ironhack')&((comments2['jobTitle']=='Founder, Donkies Technologies'))]
# Out:
#           id           name  anonymous hostProgramName  graduatingYear  \
# 1035  235469  Ryan Morrison      False            None          2016.0
#
#       isAlumni                       jobTitle       tagline  \
# 1035      True  Founder, Donkies Technologies  Great School
#
#                                                    body  \
# 1035  <span class="truncatable"><p>Ironhack gave me ...
#
#                                                 rawBody  ...   queryDate  \
# 1035  Ironhack gave me the confidence to build a tec...  ...  2017-03-28
#
#                         program             user overallScore comments  \
# 1035  Web Development Part-Time  {'image': None}          5.0       []
#
#      overall curriculum jobSupport  \
# 1035     5.0        5.0        5.0
#
#                                             review_body    school
# 1035  Ironhack gave me the confidence to build a tec...  ironhack
#
# [1 rows x 21 columns]

# %%
jobTitle_WD =['Senior Associate', 'unemployed', 'Botcave', 'Finance Analyst', 'Program Manager', 'Estudiante', 'Therapist', 'Student', 'student',
'Partner @Orion', 'Founder', 'Student', 'COO at Tender.co', 'Entrepreneur']
def jobTitle_WD_clean(row):
    for element in jobTitle_WD:
        if element in row:
            return 0
        else:
            return 1

comments2['Work_inField']=comments2['jobTitle'].apply(jobTitle_WD_clean)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-114446eede26> in <module>
#       8             return 1
#       9
# ---> 10 comments2['Work_inField']=comments2['jobTitle'].apply(jobTitle_WD_clean)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-27-114446eede26> in jobTitle_WD_clean(row)
#       3 def jobTitle_WD_clean(row):
#       4     for element in jobTitle_WD:
# ----> 5         if element in row:
#       6             return 0
#       7         else:
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
def jobTitle_DA_clean(row):
    jobTitle_DA =['Data', 'dados', 'analyst', 'Software', 'Manager', 'Junior', 'Innovation']
    for element in jobTitle_DA:
        if (element in row):
            return 1
        else:
            return 0

comments2['Work_inField']=comments2['jobTitle'].apply(jobTitle_DA_clean)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-6842e564312d> in <module>
#       7             return 0
#       8
# ----> 9 comments2['Work_inField']=comments2['jobTitle'].apply(jobTitle_DA_clean)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-23-6842e564312d> in jobTitle_DA_clean(row)
#       2     jobTitle_DA =['Data', 'dados', 'analyst', 'Software', 'Manager', 'Junior', 'Innovation']
#       3     for element in jobTitle_DA:
# ----> 4         if (element in row) & (element is not None):
#       5             return 1
#       6         else:
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
comments2[(comments2['school']=='ironhack')&((comments2['program']=='UX/UI Design Bootcamp')|(comments2['program']=='UX/UI Design Part-Time'))]['jobTitle'].unique()
# Out:
# array(['UX / UI Designer', 'UX/UI Designer', 'UX UI Designer',
#        'Product Designer', '', 'UXUI Designer', 'Product designer',
#        'ux ui designer', 'UX/UI designer', 'Ux ui designer',
#        'ux/ui product designer', 'UX Designer', 'Student', 'UX/UI Design',
#        'UX designer', 'Unemployed', 'UI Designer',
#        'Learning and Development Specialist', 'Ux/Ui Designer',
#        'UX-UI designer', 'Designer', 'UX Designer/UX Writer',
#        'UX UI designer', 'ux/ui designer', 'Head of design', None,
#        'Junior Product Designer', 'UX DESIGNER', 'UX - UI Designer',
#        'UX/UI and graphic designer', 'Teacher Assistant', 'UX UI Design',
#        'Freelancing UX/UI Designer &amp; Travel agent', 'UX/UI',
#        'UX &amp; UI Designer', 'UX DEsigner', 'co-founder at Leemur',
#        'Ux/UI Designer', 'Creative Designer',
#        'UX/UI Design Teacher Assistant', 'UX/UI Designer ',
#        'Creative Team Lead', 'Creative Manager',
#        'Creative Development Manager', 'Interaction Designer',
#        'Ux Ui Designer', 'UX/UI designer M.A Visual and Performing Arts',
#        'UXUI designer', 'Former UX/UI Student', 'student', 'UX/UI design',
#        'Industrial/ Graphic and UX/UI Designer ', 'Owner',
#        'Director of Ecommerce Operations', 'UX Researcher', 'UX ',
#        'UX/UI Designer &amp; Front End Developer',
#        'Architect &amp; UX/UI Designer', 'UX7UI', 'Front-End Developer',
#        'Product Designer ', 'Diseñador de Producto',
#        'Marketing &amp; UX specialist', 'UX/UI DESIGNER',
#        'service designer', 'UX/ UI Designer', 'Experience Designer',
#        'HIT Consultant ', 'UX / UI &amp; Front End Designer',
#        'Jr UX Architec', 'Digital Product Designer', 'LEAD UX/UI',
#        'Lead UX at Loycus', 'Digital Product Manager'], dtype=object)

# %%
jobTitle_UXUI =['Student', 'student', 'Unemployed', 'Leemur', 'Owner']
def jobTitle_UXUI_clean(row):
    for element in jobTitle_UXUI:
        if element in row:
            return 0
        else:
            return 1

comments2['Work_inField']=comments2['jobTitle'].apply(jobTitle_UXUI_clean)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-190-8560e042ebe9> in <module>
#       7             return 1
#       8
# ----> 9 comments2['Work_inField']=comments2['jobTitle'].apply(jobTitle_UXUI_clean)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-190-8560e042ebe9> in jobTitle_UXUI_clean(row)
#       2 def jobTitle_UXUI_clean(row):
#       3     for element in jobTitle_UXUI:
# ----> 4         if element in row:
#       5             return 0
#       6         else:
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
comments2[(comments2['school']=='ironhack')&((comments2['program']=='UX/UI Design Bootcamp')|(comments2['program']=='UX/UI Design Part-Time'))]['jobTitle'].unique()

# %%
comments2[comments2['school']=='ironhack']['program'].unique()
# Out:
# array(['UX/UI Design Bootcamp', 'Cyber Security Bootcamp',
#        'Data Analytics Bootcamp', 'Data Analytics Part-Time',
#        'Web Development Part-Time', 'Web Development Bootcamp', None,
#        'UX/UI Design Part-Time'], dtype=object)

# %%
comments2[comments2['school']=='ironhack']['graduatingYear'].unique()
# Out:
# array([2021., 2020., 2018., 2019., 2017., 2011., 2016., 2015., 2014.])

# %%
comments2[comments2['school']=='ironhack']['graduatingYear'].dtype
# Out:
# dtype('float64')

# %%
def price_program(row):
    if row['graduatingYear'] == 2021.0:
        if row['program'] == 'UX/UI Design Bootcamp':
            return 12.000
        elif row['program'] == 'Cyber Security Bootcamp':
            return 7.500
        elif row['program'] == 'Data Analytics Bootcamp':
            return 7.500
        elif row['program'] == 'Web Development Bootcamp':
            return 12.000
        elif row['program'] == 'UX/UI Design Part-Time':
            return 13.000
        elif row['program'] == 'Cyber Security Part-Time':
            return 7.500
        elif row['program'] == 'Data Analytics Part-Time':
            return 8.000
        elif row['program'] == 'Web Development Part-Time':
            return 13.000
    else:
        return 'check price'

# %%
comments2['price']=comments2.apply(price_program, axis=1)

# %%
comments2['price'].unique()
# Out:
# array([12.0, 7.5, 8.0, 13.0, None, 'check price'], dtype=object)

# %%
comments2.head(2)
# Out:
#        id         name  anonymous hostProgramName  graduatingYear  isAlumni  \
# 0  284372        James      False            None          2021.0     False
# 1  284341  Hugo Michon      False            None          2021.0      True
#
#                  jobTitle                                    tagline  \
# 0        UX / UI Designer  From teacher to UX/UI designer in 9 weeks
# 1  Cyber security analyst                    Exhausting but worth it
#
#                                                 body  \
# 0  <span class="truncatable"><p></p><p>I came int...
# 1  <span class="truncatable"><p></p><p>I did a fu...
#
#                                              rawBody  ...  \
# 0  <p>I came into the Ironhack full-time remote b...  ...
# 1  <p>I did a full time remote bootcamp for cyber...  ...
#
#                    program             user overallScore comments overall  \
# 0    UX/UI Design Bootcamp  {'image': None}          5.0       []     5.0
# 1  Cyber Security Bootcamp  {'image': None}          5.0       []     5.0
#
#   curriculum jobSupport                                        review_body  \
# 0        5.0        5.0  I came into the Ironhack full-time remote boot...
# 1        5.0        5.0  I did a full time remote bootcamp for cybersec...
#
#      school price
# 0  ironhack  12.0
# 1  ironhack   7.5
#
# [2 rows x 22 columns]

# %%
comments2[(comments2['school']=='ironhack')|comments2['program']=='ironhack']['jobTitle'].unique()
# Out:
# array([], dtype=object)

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# <ipython-input-160-7111c633f1e2>:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   locations_df = json_normalize(locations)
# app-academy
# springboard

# %%
locations_list
# Out:
# [      id               description  country.id   country.name country.abbrev  \
#  0  15901           Berlin, Germany        57.0        Germany             DE
#  1  16022       Mexico City, Mexico        29.0         Mexico             MX
#  2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
#  3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
#  4  16109             Paris, France        38.0         France             FR
#  5  16375  Miami, FL, United States         1.0  United States             US
#  6  16376             Madrid, Spain        12.0          Spain             ES
#  7  16377          Barcelona, Spain        12.0          Spain             ES
#  8  16709          Lisbon, Portugal        28.0       Portugal             PT
#  9  17233                    Online         NaN            NaN            NaN
#
#     city.id    city.name city.keyword  state.id state.name state.abbrev  \
#  0  31156.0       Berlin       berlin       NaN        NaN          NaN
#  1  31175.0  Mexico City  mexico-city       NaN        NaN          NaN
#  2  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
#  3  31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
#  4  31136.0        Paris        paris       NaN        NaN          NaN
#  5     31.0        Miami        miami      11.0    Florida           FL
#  6  31052.0       Madrid       madrid       NaN        NaN          NaN
#  7  31170.0    Barcelona    barcelona       NaN        NaN          NaN
#  8  31075.0       Lisbon       lisbon       NaN        NaN          NaN
#  9      NaN          NaN          NaN       1.0     Online       Online
#
#    state.keyword    school  school_id
#  0           NaN  ironhack      10828
#  1           NaN  ironhack      10828
#  2           NaN  ironhack      10828
#  3           NaN  ironhack      10828
#  4           NaN  ironhack      10828
#  5       florida  ironhack      10828
#  6           NaN  ironhack      10828
#  7           NaN  ironhack      10828
#  8           NaN  ironhack      10828
#  9        online  ironhack      10828  ,
#        id                       description  country.id   country.name  \
#  0  15704  San Francisco, CA, United States         1.0  United States
#  1  15705  New York City, NY, United States         1.0  United States
#  2  15862                            Online         NaN            NaN
#
#    country.abbrev  state.id  state.name state.abbrev state.keyword  city.id  \
#  0             US         6  California           CA    california     13.0
#  1             US        34    New York           NY      new-york   1507.0
#  2            NaN         1      Online       Online        online      NaN
#
#         city.name   city.keyword       school  school_id
#  0  San Francisco  san-francisco  app-academy      10525
#  1            NYC  new-york-city  app-academy      10525
#  2            NaN            NaN  app-academy      10525  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  16013      Online         1     Online       Online        online
#
#          school  school_id
#  0  springboard      11035  ]

# %%
locations = pd.concat(locations_list)
locations
# Out:
#       id                       description  country.id   country.name  \
# 0  15901                   Berlin, Germany        57.0        Germany
# 1  16022               Mexico City, Mexico        29.0         Mexico
# 2  16086            Amsterdam, Netherlands        59.0    Netherlands
# 3  16088                 Sao Paulo, Brazil        42.0         Brazil
# 4  16109                     Paris, France        38.0         France
# 5  16375          Miami, FL, United States         1.0  United States
# 6  16376                     Madrid, Spain        12.0          Spain
# 7  16377                  Barcelona, Spain        12.0          Spain
# 8  16709                  Lisbon, Portugal        28.0       Portugal
# 9  17233                            Online         NaN            NaN
# 0  15704  San Francisco, CA, United States         1.0  United States
# 1  15705  New York City, NY, United States         1.0  United States
# 2  15862                            Online         NaN            NaN
# 0  16013                            Online         NaN            NaN
#
#   country.abbrev  city.id      city.name   city.keyword  state.id  state.name  \
# 0             DE  31156.0         Berlin         berlin       NaN         NaN
# 1             MX  31175.0    Mexico City    mexico-city       NaN         NaN
# 2             NL  31168.0      Amsterdam      amsterdam       NaN         NaN
# 3             BR  31121.0      Sao Paulo      sao-paulo       NaN         NaN
# 4             FR  31136.0          Paris          paris       NaN         NaN
# 5             US     31.0          Miami          miami      11.0     Florida
# 6             ES  31052.0         Madrid         madrid       NaN         NaN
# 7             ES  31170.0      Barcelona      barcelona       NaN         NaN
# 8             PT  31075.0         Lisbon         lisbon       NaN         NaN
# 9            NaN      NaN            NaN            NaN       1.0      Online
# 0             US     13.0  San Francisco  san-francisco       6.0  California
# 1             US   1507.0            NYC  new-york-city      34.0    New York
# 2            NaN      NaN            NaN            NaN       1.0      Online
# 0            NaN      NaN            NaN            NaN       1.0      Online
#
#   state.abbrev state.keyword       school  school_id
# 0          NaN           NaN     ironhack      10828
# 1          NaN           NaN     ironhack      10828
# 2          NaN           NaN     ironhack      10828
# 3          NaN           NaN     ironhack      10828
# 4          NaN           NaN     ironhack      10828
# 5           FL       florida     ironhack      10828
# 6          NaN           NaN     ironhack      10828
# 7          NaN           NaN     ironhack      10828
# 8          NaN           NaN     ironhack      10828
# 9       Online        online     ironhack      10828
# 0           CA    california  app-academy      10525
# 1           NY      new-york  app-academy      10525
# 2       Online        online  app-academy      10525
# 0       Online        online  springboard      11035

# %%
courses = pd.concat(courses_list)
courses
# Out:
#                                           courses       school  school_id
# 0                         Cyber Security Bootcamp     ironhack      10828
# 1                         Cybersecurity Part-Time     ironhack      10828
# 2                         Data Analytics Bootcamp     ironhack      10828
# 3                        Data Analytics Part-Time     ironhack      10828
# 4                           UX/UI Design Bootcamp     ironhack      10828
# 5                          UX/UI Design Part-Time     ironhack      10828
# 6                        Web Development Bootcamp     ironhack      10828
# 7                       Web Development Part-Time     ironhack      10828
# 0                                   Bootcamp Prep  app-academy      10525
# 1              Software Engineer Track: In-Person  app-academy      10525
# 2                                App Academy Open  app-academy      10525
# 3                 Software Engineer Track: Online  app-academy      10525
# 0                     Cyber Security Career Track  springboard      11035
# 1                     Data Analytics Career Track  springboard      11035
# 2                   Data Engineering Career Track  springboard      11035
# 3                       Data Science Career Track  springboard      11035
# 4                  Data Science Career Track Prep  springboard      11035
# 5                  Introduction to Data Analytics  springboard      11035
# 6                          Introduction to Design  springboard      11035
# 7               Software Engineering Career Track  springboard      11035
# 8   Software Engineering Career Track Prep Course  springboard      11035
# 9                       UI/UX Design Career Track  springboard      11035
# 10                                UX Career Track  springboard      11035

# %%
badges = pd.concat(badges_list)
badges
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 0          <p>School offers fully online courses</p>  app-academy      10525
# 1  <p>School offers part-time and evening classes...  app-academy      10525
# 0          <p>School offers fully online courses</p>  springboard      11035
# 1  <p>School offers part-time and evening classes...  springboard      11035
# 2             <p>School guarantees job placement</p>  springboard      11035

# %%
# any data cleaning still missing here? take a look at the description
schools = pd.concat(schools_list)
schools
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0  www.springboard.com/?utm_source=switchup&utm_m...
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>App Academy is a ...
# 0  <span class="truncatable"><p>Springboard is an...
#
#                                              LogoUrl       school  school_id
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...     ironhack      10828
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  app-academy      10525
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  springboard      11035
